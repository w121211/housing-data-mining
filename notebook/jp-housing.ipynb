# %%
from pathlib import Path
import pandas as pd

csvpath = Path().resolve().parent / 'data/All_20053_20222/01_Hokkaido_20053_20222.csv'
df = pd.read_csv(csvpath, encoding="cp932")
df.head()
# Out:
# /tmp/ipykernel_6497/2412592001.py:5: DtypeWarning: Columns (11,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csvpath, encoding="cp932")
#    No         種類   地域  市区町村コード 都道府県名   市区町村名  地区名 最寄駅：名称 最寄駅：距離（分）   取引価格（総額）  \
# 0   1  宅地(土地と建物)  住宅地     1101   北海道  札幌市中央区  旭ケ丘   円山公園        26  100000000
# 1   2     宅地(土地)  住宅地     1101   北海道  札幌市中央区  旭ケ丘   円山公園        26   32000000
# 2   3     宅地(土地)  住宅地     1101   北海道  札幌市中央区  旭ケ丘   円山公園        25   24000000
# 3   4     宅地(土地)  住宅地     1101   北海道  札幌市中央区  旭ケ丘   円山公園        25   26000000
# 4   5     宅地(土地)  住宅地     1101   北海道  札幌市中央区  旭ケ丘   円山公園        25   28000000
#
#    ...  今後の利用目的 前面道路：方位 前面道路：種類  前面道路：幅員（ｍ）         都市計画 建ぺい率（％） 容積率（％）  \
# 0  ...       住宅       東      市道        15.0      第１種住居地域    60.0  200.0
# 1  ...       住宅       東      市道         7.2  第１種低層住居専用地域    40.0   80.0
# 2  ...       住宅       東      市道         7.2      第１種住居地域    60.0  200.0
# ...

# %%
df['地域'].unique()
# Out:
# array(['住宅地', nan, '商業地', '工業地', '宅地見込地'], dtype=object)
